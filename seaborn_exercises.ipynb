# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
##SET 1

# %%
## Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas 
## to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?
# ex. tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
## 1. What does the distribution of petal lengths look like?
sns.histplot(iris.petal_length)
plt.show()

# %%
## 2. Is there a correlation between petal length and petal width?
sns.relplot(x='petal_length', y ='petal_width', data=iris)
# Yes as petal lenght increases so does width

# %%
## 3. Would it be reasonable to predict species based on sepal width and sepal length?

# %%
sns.relplot(x='sepal_length', y ='sepal_width', hue='species', data=iris)

# %%
## 4. Which features would be best used to predict species?
# make a pairplot to see better
sns.relplot(data=iris, x="sepal_width", y="sepal_length", hue='species') 
sns.relplot(data=iris, x="petal_width", y="petal_length", hue='species')

# %%
###SET 2

# %%
## 1.Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. 
## Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. 
## What do you notice?
anscombe = sns.load_dataset('anscombe')
anscombe
# goup by dataset column
anscombe.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
sns.relplot(data=anscombe, x= 'x', y='y', col='dataset')

# %%
from pydataset import data

# %%
## 2. Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of 
## the different insect sprays.
#what does regplot do?
#Load the InsectSprays dataset and read it's documentation.
# Create a boxplot that shows the effectiveness of the different insect sprays.
insect_sprays = data("InsectSprays")
insect_sprays.head()
# create a boxplot
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
sns.boxplot( data= insect_sprays,x='count', y='spray')
# Out:
# <AxesSubplot:xlabel='count', ylabel='spray'>

# %%
from pydataset import swiss
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-da5cc833dfb1> in <module>
# ----> 1 from pydataset import swiss
#
# ImportError: cannot import name 'swiss' from 'pydataset' (/usr/local/anaconda3/lib/python3.8/site-packages/pydataset/__init__.py)

# %%
## 3. Load the swiss dataset and read it's documentation. The swiss dataset is available from pydatset rather than 
## seaborn.
#catholic make a function
#use .apply
insect_sprays = data("InsectSprays")
swiss = data('swiss')
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
## 4. Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular
## items and the revenue produced by each.
from env import user, password, host
def get_db_url(user, password, host, db_name):
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'
url = get_db_url = get_db_url(user, password, host, 'chipotle')
chipotle = pd.read_sql(' SELECT * FROM orders', url)
#find the four most common items

# counting the frequency of each element
freq = chipotle.item_name.value_counts()
print("Printing the frequency")
display(freq)
#Chicken Bowl                             726
#Chicken Burrito                          553
#Chips and Guacamole                      479
#Steak Burrito                            368
# Out:
# Printing the frequency
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# ...

# %%
orders
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-7651accba901> in <module>
# ----> 1 orders
#
# NameError: name 'orders' is not defined

# %%
best_sellers = chipotle.orders.groupby('item_name').quantity.sum().nlargest(4)
best_sellers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-d045f6b7aa6b> in <module>
# ----> 1 best_sellers = chipotle.orders.groupby('item_name').quantity.sum().nlargest(4)
#       2 best_sellers
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'orders'

# %%
## 5. Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual 
## subject's reaction times and a more prominant line showing the average change in reaction time.

# Loading the sleepdstudy data 
sleepstudy = data("sleepstudy")
# Creating a line chart of reaction times
sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', hue= 'Subject')
#Chart the average reaction time
sns.lineplot(data = sleepstudy, x = 'Days', y = 'Reaction', color = 'black', estimator = 'mean')
plt.show()
